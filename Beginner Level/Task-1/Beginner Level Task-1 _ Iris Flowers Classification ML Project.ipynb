# %% [markdown]
# # **LGM-VIP Data Science Internship Programme**##
#
# ###**Beginner Level Task-1 : Iris Flowers Classification ML Project**
#
# ###**Author : S Sreevatsav**
#
# ###**Language : Python**

# %% [markdown]
# ## **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## **Loading Data**

# %%
dataset = pd.read_csv("iris_data.csv")
dataset.head()
# Out:
#    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm       Species
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SepalLengthCm   150 non-null    float64
#  1   SepalWidthCm    150 non-null    float64
#  2   PetalLengthCm   150 non-null    float64
#  3   PetalWidthCm    150 non-null    float64
#  4   Species         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset.columns
# Out:
# Index(['SepalLengthCm ', 'SepalWidthCm ', 'PetalLengthCm ', 'PetalWidthCm ',
#        'Species'],
#       dtype='object')

# %%
dataset['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# ## **Visualization**

# %%
sns.pairplot(dataset)

# %%
plt.rcParams["figure.figsize"] = (16, 8)
sns.lineplot(x='SepalLengthCm ',y='SepalWidthCm ',data=dataset)
plt.show()

# %%
sns.lineplot(x='PetalLengthCm ',y='PetalWidthCm ',data=dataset)
plt.show()

# %%
sns.boxplot(x='PetalLengthCm ',y='PetalWidthCm ',data=dataset)
plt.show()

# %%
sns.boxplot(x='SepalLengthCm ',y='SepalWidthCm ',data=dataset)
plt.show()

# %%
dataset.plot.hist(alpha=0.5)
plt.show()

# %%
sns.barplot('SepalLengthCm ',y='SepalWidthCm ',data=dataset)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.barplot('PetalLengthCm ',y='PetalWidthCm ',data=dataset)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
px.scatter(data_frame=dataset, x='SepalLengthCm ',y='SepalWidthCm ',  color='Species')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ecf3a535-a284-43be-80a4-d43e5639ca1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ecf3a535-a284-43be-80a4-d43e5639ca1d")) {
#                     Plotly.newPlot(
#                         'ecf3a535-a284-43be-80a4-d43e5639ca1d',
# ...

# %%
px.scatter(data_frame=dataset, x='PetalLengthCm ',y='PetalWidthCm ',  color='Species')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="91aec64f-066b-4771-b5e1-e7c1684f9660" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("91aec64f-066b-4771-b5e1-e7c1684f9660")) {
#                     Plotly.newPlot(
#                         '91aec64f-066b-4771-b5e1-e7c1684f9660',
# ...

# %% [markdown]
# # **Correaltion Matrix**

# %%
corr_matrix=dataset.corr()
corr_matrix
# Out:
#                 SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm
# SepalLengthCm         1.000000      -0.109369        0.871754       0.817954
# SepalWidthCm         -0.109369       1.000000       -0.420516      -0.356544
# PetalLengthCm         0.871754      -0.420516        1.000000       0.962757
# PetalWidthCm          0.817954      -0.356544        0.962757       1.000000

# %%
sns.heatmap(corr_matrix)

# %% [markdown]
# ##Shuffling Dataset

# %%
dataset=dataset.sample(frac=1)
dataset
# Out:
#      SepalLengthCm   SepalWidthCm   ...  PetalWidthCm          Species
# 32              5.2            4.1  ...            0.1     Iris-setosa
# 47              4.6            3.2  ...            0.2     Iris-setosa
# 114             5.8            2.8  ...            2.4  Iris-virginica
# 148             6.2            3.4  ...            2.3  Iris-virginica
# 14              5.8            4.0  ...            0.2     Iris-setosa
# ..              ...            ...  ...            ...             ...
# 128             6.4            2.8  ...            2.1  Iris-virginica
# 102             7.1            3.0  ...            2.1  Iris-virginica
# 27              5.2            3.5  ...            0.2     Iris-setosa
# 131             7.9            3.8  ...            2.0  Iris-virginica
# 40              5.0            3.5  ...            0.3     Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# ## **Splitting of Data and Feature Scaling**

# %%
y=dataset.iloc[:,4]
x=dataset.iloc[:,0:4]
y
# Out:
# 32        Iris-setosa
# 47        Iris-setosa
# 114    Iris-virginica
# 148    Iris-virginica
# 14        Iris-setosa
#             ...
# 128    Iris-virginica
# 102    Iris-virginica
# 27        Iris-setosa
# 131    Iris-virginica
# 40        Iris-setosa
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
x=StandardScaler().fit_transform(x)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_y=LabelEncoder()
y=label_encoder_y.fit_transform(y)
y
# Out:
# array([0, 0, 2, 2, 0, 2, 1, 0, 2, 1, 0, 0, 1, 1, 2, 1, 0, 2, 2, 1, 2, 2,
#        1, 2, 2, 0, 0, 2, 0, 0, 1, 0, 0, 2, 1, 0, 2, 0, 2, 2, 2, 0, 1, 1,
#        1, 2, 1, 1, 2, 2, 0, 1, 1, 0, 1, 2, 1, 0, 1, 0, 1, 0, 2, 2, 0, 1,
#        2, 2, 1, 2, 0, 1, 0, 1, 1, 1, 0, 1, 0, 0, 2, 0, 1, 0, 2, 2, 2, 1,
#        2, 2, 1, 1, 0, 0, 1, 1, 2, 1, 1, 0, 0, 2, 2, 1, 2, 0, 1, 0, 0, 2,
#        2, 2, 2, 2, 1, 2, 0, 1, 1, 0, 0, 1, 1, 2, 0, 1, 1, 1, 2, 0, 0, 0,
#        0, 1, 0, 1, 2, 1, 1, 0, 0, 2, 0, 2, 1, 2, 2, 0, 2, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

# %% [markdown]
# # **Training and Testing of Model**

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(x_test)
y_pred,y_test
# Out:
# (array([1, 2, 2, 0, 0, 0, 2, 2, 0, 1, 0, 1, 1, 2, 2]),
#  array([1, 2, 2, 0, 0, 0, 2, 2, 0, 1, 0, 1, 1, 1, 2]))

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333
